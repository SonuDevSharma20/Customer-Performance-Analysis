# %% [markdown]
# IMPORTED PANDAS

# %%
import pandas as pd

# %% [markdown]
# READING CSV FILE

# %%
df = pd.read_csv("Desktop/Projects/E Commerce Analysis/Raw CSV/mini_project_store.csv")
print(df)
# Out:
#       Row ID        Order ID Order Date Order Date - Copy Ship Date  \
# 0          1  CA-2016-152156    11/8/16        11-08-2016  11/11/16
# 1          2  CA-2016-152156    11/8/16        11-08-2016  11/11/16
# 2          3  CA-2016-138688    6/12/16        06-12-2016   6/16/16
# 3          4  US-2015-108966   10/11/15        10-11-2015  10/18/15
# 4          5  US-2015-108966   10/11/15        10-11-2015  10/18/15
# ...      ...             ...        ...               ...       ...
# 9989    9990  CA-2014-110422    1/21/14               NaN   1/23/14
# 9990    9991  CA-2017-121258    2/26/17               NaN    3/3/17
# 9991    9992  CA-2017-121258    2/26/17               NaN    3/3/17
# 9992    9993  CA-2017-121258    2/26/17               NaN    3/3/17
# 9993    9994  CA-2017-119914     5/4/17        05-04-2017    5/9/17
#
#            Ship Mode Customer ID     Customer Name    Segment        Country  \
# ...

# %% [markdown]
# DISPLAYING TOP 5 DATA

# %%
df.head(6)
# Out:
#    Row ID        Order ID Order Date Order Date - Copy Ship Date  \
# 0       1  CA-2016-152156    11/8/16        11-08-2016  11/11/16
# 1       2  CA-2016-152156    11/8/16        11-08-2016  11/11/16
# 2       3  CA-2016-138688    6/12/16        06-12-2016   6/16/16
# 3       4  US-2015-108966   10/11/15        10-11-2015  10/18/15
# 4       5  US-2015-108966   10/11/15        10-11-2015  10/18/15
# 5       6  CA-2014-115812     6/9/14        06-09-2014   6/14/14
#
#         Ship Mode Customer ID    Customer Name    Segment        Country  ...  \
# 0    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 1    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate  United States  ...
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
# ...

# %% [markdown]
# FINDING INFO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Row ID             9994 non-null   int64
#  1   Order ID           9994 non-null   object
#  2   Order Date         9994 non-null   object
#  3   Order Date - Copy  4042 non-null   object
#  4   Ship Date          9994 non-null   object
#  5   Ship Mode          9994 non-null   object
#  6   Customer ID        9994 non-null   object
#  7   Customer Name      9994 non-null   object
#  8   Segment            9994 non-null   object
#  9   Country            9994 non-null   object
#  10  City               9994 non-null   object
#  11  State              9994 non-null   object
#  12  Postal Code        9994 non-null   int64
#  13  Region             9994 non-null   object
#  14  Product ID         9994 non-null   object
#  15  Category           9994 non-null   object
# ...

# %% [markdown]
# FINDING DESCRIPTION

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# FINDING TOTAL RAWS AND COLOUMNS

# %%
rows, columns = df.shape
print("Total Rows:", rows)
print("Total Columns:", columns)
# Out:
# Total Rows: 9994
# Total Columns: 22

# %% [markdown]
# FINDING NULL VALUES

# %%
df.isnull().sum()
# Out:
# Row ID                  0
# Order ID                0
# Order Date              0
# Order Date - Copy    5952
# Ship Date               0
# Ship Mode               0
# Customer ID             0
# Customer Name           0
# Segment                 0
# Country                 0
# City                    0
# State                   0
# Postal Code             0
# Region                  0
# Product ID              0
# Category                0
# Sub-Category            0
# Product Name            0
# Sales                   0
# Quantity                0
# Discount                0
# Profit                  0
# dtype: int64

# %% [markdown]
# REMOVING DUPLICATE VALUES

# %%
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Order Date - Copy, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# FORMATING DATES

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df.head(14)
# Out:
# C:\Users\dharmesh\AppData\Local\Temp\ipykernel_3404\1484800439.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Order Date'] = pd.to_datetime(df['Order Date'])
#     Row ID        Order ID Order Date Order Date - Copy Ship Date  \
# 0        1  CA-2016-152156 2016-11-08        11-08-2016  11/11/16
# 1        2  CA-2016-152156 2016-11-08        11-08-2016  11/11/16
# 2        3  CA-2016-138688 2016-06-12        06-12-2016   6/16/16
# 3        4  US-2015-108966 2015-10-11        10-11-2015  10/18/15
# 4        5  US-2015-108966 2015-10-11        10-11-2015  10/18/15
# 5        6  CA-2014-115812 2014-06-09        06-09-2014   6/14/14
# 6        7  CA-2014-115812 2014-06-09        06-09-2014   6/14/14
# 7        8  CA-2014-115812 2014-06-09        06-09-2014   6/14/14
# 8        9  CA-2014-115812 2014-06-09        06-09-2014   6/14/14
# ...

# %%
df['Order Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Order Date'].head(14)
# Out:
# 0    2016-11-08
# 1    2016-11-08
# 2    2016-06-12
# 3    2015-10-11
# 4    2015-10-11
# 5    2014-06-09
# 6    2014-06-09
# 7    2014-06-09
# 8    2014-06-09
# 9    2014-06-09
# 10   2014-06-09
# 11   2014-06-09
# 12   2017-04-15
# 13   2016-12-05
# Name: Order Date, dtype: datetime64[ns]

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date Order Date - Copy Ship Date  \
# 0       1  CA-2016-152156 2016-11-08        11-08-2016  11/11/16
# 1       2  CA-2016-152156 2016-11-08        11-08-2016  11/11/16
# 2       3  CA-2016-138688 2016-06-12        06-12-2016   6/16/16
# 3       4  US-2015-108966 2015-10-11        10-11-2015  10/18/15
# 4       5  US-2015-108966 2015-10-11        10-11-2015  10/18/15
#
#         Ship Mode Customer ID    Customer Name    Segment        Country  ...  \
# 0    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 1    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate  United States  ...
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
#
#   Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# Calculating Saling Price

# %%
df["Saling Price"] = df["Sales"] * df["Quantity"]
print(df)
df.head()
# Out:
#       Row ID        Order ID Order Date Order Date - Copy Ship Date  \
# 0          1  CA-2016-152156 2016-11-08        11-08-2016  11/11/16
# 1          2  CA-2016-152156 2016-11-08        11-08-2016  11/11/16
# 2          3  CA-2016-138688 2016-06-12        06-12-2016   6/16/16
# 3          4  US-2015-108966 2015-10-11        10-11-2015  10/18/15
# 4          5  US-2015-108966 2015-10-11        10-11-2015  10/18/15
# ...      ...             ...        ...               ...       ...
# 9989    9990  CA-2014-110422 2014-01-21               NaN   1/23/14
# 9990    9991  CA-2017-121258 2017-02-26               NaN    3/3/17
# 9991    9992  CA-2017-121258 2017-02-26               NaN    3/3/17
# 9992    9993  CA-2017-121258 2017-02-26               NaN    3/3/17
# 9993    9994  CA-2017-119914 2017-05-04        05-04-2017    5/9/17
#
#            Ship Mode Customer ID     Customer Name    Segment        Country  \
# ...

# %% [markdown]
# Calculating Purchasing Price

# %%
df["Purchasing Price"] = df["Saling Price"] - df["Profit"]
print(df)
df.head()
# Out:
#       Row ID        Order ID Order Date Order Date - Copy Ship Date  \
# 0          1  CA-2016-152156 2016-11-08        11-08-2016  11/11/16
# 1          2  CA-2016-152156 2016-11-08        11-08-2016  11/11/16
# 2          3  CA-2016-138688 2016-06-12        06-12-2016   6/16/16
# 3          4  US-2015-108966 2015-10-11        10-11-2015  10/18/15
# 4          5  US-2015-108966 2015-10-11        10-11-2015  10/18/15
# ...      ...             ...        ...               ...       ...
# 9989    9990  CA-2014-110422 2014-01-21               NaN   1/23/14
# 9990    9991  CA-2017-121258 2017-02-26               NaN    3/3/17
# 9991    9992  CA-2017-121258 2017-02-26               NaN    3/3/17
# 9992    9993  CA-2017-121258 2017-02-26               NaN    3/3/17
# 9993    9994  CA-2017-119914 2017-05-04        05-04-2017    5/9/17
#
#            Ship Mode Customer ID     Customer Name    Segment        Country  \
# ...

# %% [markdown]
# Count of Products Sale by Category

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %% [markdown]
# Count of products sale by Sub-Categories

# %%
df['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %% [markdown]
# Count of state

# %%
df['State'].value_counts()
# Out:
# State
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %% [markdown]
# Count of City

# %%
df['City'].value_counts()
# Out:
# City
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
#                 ...
# Abilene            1
# Montebello         1
# Kissimmee          1
# Danbury            1
# Springdale         1
# Name: count, Length: 531, dtype: int64

# %%
df.to_csv("mydata.csv", index=True)

# %%
print(df.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Date - Copy', 'Ship Date',
#        'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country',
#        'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Saling Price', 'Purchasing Price'],
#       dtype='object')
